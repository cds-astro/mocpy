# %%
# %matplotlib inline

# %%
import sys
sys.path.append('../pymoc')

# %% [markdown]
# Let's start by loading a local MOC and plotting it

# %%
from moc import MOC
m1 = MOC.from_file('/data/MOC/examples/P-SDSS9-r.fits')
m1.plot(title='SDSS9 band r coverage', coord='C')
# Out:
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.

# %% [markdown]
# Now, we load MOC for GALEX GR6 AIS FUV:

# %%
m2 = MOC.from_file('/data/MOC/examples/P-GALEXGR6-AIS-FUV.fits')
m2.plot(title='GALEX GR6 AIS FUV coverage')
# Out:
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.

# %% [markdown]
# We can compute the intersection between the 2 MOC:

# %%
m_intersect = m1.intersection(m2)
m_intersect.plot()
# Out:
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.

# %% [markdown]
# And save the result in FITS (official serialization):

# %%
m_intersect.write('/home/boch/SDSS_inter_GALEX.fits')

# %% [markdown]
# MOC can also be saved in JSON:

# %%
m_intersect.write('/home/boch/SDSS_inter_GALEX.json', format='json')
