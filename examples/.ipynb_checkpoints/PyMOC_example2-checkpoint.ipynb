# %% [markdown]
# *Creating a MOC from a set of coordinates*

# %%
# %matplotlib inline

# %%
import sys
sys.path.append('../pymoc')
import warnings 
warnings.filterwarnings('ignore')
from moc import MOC

# %% [markdown]
# Let's load a VizieR catalog

# %%
from astropy.coordinates import SkyCoord
from astropy import units as u
from astroquery.vizier import Vizier
Vizier.ROW_LIMIT = -1

table = Vizier.get_catalogs('I/293/npm2cros')[0]
print table
# Out:
#  _RAJ2000  _DEJ2000  OID   n_OID ... u_Period  RAJ2000   DEJ2000
#    deg       deg                 ...             deg       deg
# --------- --------- ------ ----- ... -------- --------- ---------
#   0.00271  62.01222 270915     B ...            0.00271  62.01222
#   0.01521  35.36286    195     B ...            0.01521  35.36286
#   0.01669  18.40698 287959     B ...            0.01669  18.40698
#   0.01717  57.10467 275753       ...            0.01717  57.10467
#   0.02500 -59.74675 170899     B ...            0.02500 -59.74675
#   0.02721  35.36692  64625     B ...            0.02721  35.36692
#   0.02733  25.88647  25131     B ...            0.02733  25.88647
#   0.02771  56.65331 251805     B ...            0.02771  56.65331
#   0.02875  20.23736  25281     B ...        :   0.02875  20.23736
#   0.03037  18.73808  25257     B ...            0.03037  18.73808
#       ...       ...    ...   ... ...      ...       ...       ...
# 359.96370  11.67370 305881     B ...          359.96370  11.67370
# 359.96667 -34.87000 123441     B ...          359.96667 -34.87000
# 359.96979  29.82978 160439     B ...          359.96979  29.82978
# 359.97092  29.11065 230761       ...          359.97092  29.11065
# 359.97617  56.97967   6864     B ...          359.97617  56.97967
# 359.98449  55.69593 399973       ...          359.98449  55.69593
# 359.98833  51.56372 270806     B ...          359.98833  51.56372
# 359.98917 -58.03389 172595     B ...          359.98917 -58.03389
# 359.99159 -12.90878 318120       ...          359.99159 -12.90878
# 359.99279  12.74639 133592     B ...          359.99279  12.74639
# Length = 334040 rows

# %% [markdown]
# Let's create a MOC from the coordinates of this table

# %%
moc = MOC.from_table(table, '_RAJ2000', '_DEJ2000', 6)
moc.plot(coord='G')
# Out:
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.
