# %% [markdown]
# *Creating a MOC from a set of coordinates*

# %%
# %matplotlib inline

# %%
import sys
sys.path.append('../pymoc')
import warnings 
warnings.filterwarnings('ignore')
from moc import MOC

# %% [markdown]
# Let's load a VizieR catalog

# %%
from astropy.coordinates import SkyCoord
from astropy import units as u
from astroquery.vizier import Vizier
Vizier.ROW_LIMIT = -1

table = Vizier.get_catalogs('I/293/npm2cros')[0]
print table
# Out:
# _RAJ2000 _DEJ2000   NPM2       Star     KLA ...  col  n_mag n_col tyc hip
#   deg      deg                              ...  mag
# -------- -------- -------- ------------ --- ... ----- ----- ----- --- ---
# 339.6383  83.1667 +83.0016    LP 002-38 HPM ...    --     6     0
# 339.6383  83.1667 +83.0016      G265-48 HPM ...    --     4     0
# 349.5308  83.0106 +83.0022       AN CEP VAR ...    --     0     0   T   H
# 349.5308  83.0106 +83.0022       AN CEP SRA ...    --     4     0   T   H
# 323.8542  82.9972 +82.0030       W18675 UBV ...  0.62     1     1   T
# 332.1079  82.7475 +82.0055 HS 2209+8229  WD ...    --     4     0
# 332.9337  82.6078 +82.0059   LP 011-251 HPM ...    --     6     0
# 335.0887  82.9708 +82.0065    BD+82 688 HPM ...    --     6     0   T
# 337.1192  82.7639 +82.0074       W19302 UBV ...  1.17     1     1   T   H
# 337.2746  82.6622 +82.0075    LP 002-13 HPM ...    --     6     0
#      ...      ...      ...          ... ... ...   ...   ...   ... ... ...
# 257.2275 -23.0942 -23.0151       SS 296 ELS ...    --     6     0
# 267.9896 -23.0122 -23.0162   CMC 206819 CMC ...    --     3     0   T
# 267.9896 -23.0122 -23.0162  ARK-DOK72 2 ELS ...    --     0     0   T
# 270.2446 -23.0322 -23.0164   CMC 206869 CMC ...    --     3     0   T
# 270.2446 -23.0322 -23.0164       WY SGR  EA ...    --     4     0   T
# 270.3375 -23.0006 -23.0165    STONE 1-1 COM ...    --     3     0   T
# 270.4429 -23.0200 -23.0166     39(M 20) UNK ...    --     3     0
# 270.4742 -23.0289 -23.0167    STONE 1-6 COM ...    --     3     0   T
# 271.3571 -23.0056 -23.0168 ARK-DOK72 12 ELS ...    --     0     0   T
# 271.3571 -23.0056 -23.0168     LSS 4637  OB ...    --     4     0   T
# Length = 46887 rows

# %% [markdown]
# Let's create a MOC from the coordinates of this table

# %%
moc = MOC.from_table(table, '_RAJ2000', '_DEJ2000', 6)
moc.plot(coord='G')
# Out:
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.

# %%
type(table[0])
# Out:
# astropy.table.row.Row
