# %%
# %matplotlib inline

# %%
import warnings 
warnings.filterwarnings('ignore')
from mocpy import MOC

# %%
from astroquery.vizier import Vizier
Vizier.ROW_LIMIT = -1

table = Vizier.get_catalogs('I/293/npm2cros')[0]

# %%
moc = MOC.from_file('/data/MOC/examples/P-GALEXGR6-AIS-FUV.fits')
moc.plot()
# Out:
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.

# %%
print table
# Out:
# _RAJ2000 _DEJ2000   NPM2       Star     KLA ...  col  n_mag n_col tyc hip
#   deg      deg                              ...  mag
# -------- -------- -------- ------------ --- ... ----- ----- ----- --- ---
# 339.6383  83.1667 +83.0016    LP 002-38 HPM ...    --     6     0
# 339.6383  83.1667 +83.0016      G265-48 HPM ...    --     4     0
# 349.5308  83.0106 +83.0022       AN CEP VAR ...    --     0     0   T   H
# 349.5308  83.0106 +83.0022       AN CEP SRA ...    --     4     0   T   H
# 323.8542  82.9972 +82.0030       W18675 UBV ...  0.62     1     1   T
# 332.1079  82.7475 +82.0055 HS 2209+8229  WD ...    --     4     0
# 332.9337  82.6078 +82.0059   LP 011-251 HPM ...    --     6     0
# 335.0887  82.9708 +82.0065    BD+82 688 HPM ...    --     6     0   T
# 337.1192  82.7639 +82.0074       W19302 UBV ...  1.17     1     1   T   H
# 337.2746  82.6622 +82.0075    LP 002-13 HPM ...    --     6     0
#      ...      ...      ...          ... ... ...   ...   ...   ... ... ...
# ...

# %%
filtered_table = moc.filter_table(table, '_RAJ2000', '_DEJ2000')

# %%
print filtered_table
# Out:
# _RAJ2000 _DEJ2000   NPM2       Star    KLA ... n_mag n_col tyc hip
# -------- -------- -------- ----------- --- ... ----- ----- --- ---
# 339.6383  83.1667 +83.0016   LP 002-38 HPM ...     6     0
# 339.6383  83.1667 +83.0016     G265-48 HPM ...     4     0
# 349.5308  83.0106 +83.0022      AN CEP VAR ...     0     0   T   H
# 349.5308  83.0106 +83.0022      AN CEP SRA ...     4     0   T   H
# 323.8542  82.9972 +82.0030      W18675 UBV ...     1     1   T
# 335.0887  82.9708 +82.0065   BD+82 688 HPM ...     6     0   T
# 337.1192  82.7639 +82.0074      W19302 UBV ...     1     1   T   H
# 337.2746  82.6622 +82.0075   LP 002-13 HPM ...     6     0
# 338.3379  82.3692 +82.0079  LP 002-604 HPM ...     6     0
#   328.96  81.3192 +81.0032 GRW+80:5458 HPM ...     6     0   T
#      ...      ...      ...         ... ... ...   ...   ... ... ...
# 291.8692 -22.5103 -22.2062   V1147 SGR RRA ...     4     0
# 292.3187 -22.6778 -22.2070  STEPH2 163 ELS ...     3     0
# ...

# %%
m1 = MOC.from_table(table, '_RAJ2000', '_DEJ2000', 5)

m2 = MOC.from_table(filtered_table, '_RAJ2000', '_DEJ2000', 5)

m1.plot()
m2.plot()
