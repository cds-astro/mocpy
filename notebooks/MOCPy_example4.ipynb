# %%
# %matplotlib inline

from mocpy import MOC

# %%
m1 = MOC.from_vizier_table('VI/137/gum_qso', nside=512)
print(m1.max_order)
m1.plot( coord='G')
# Out:
# 9

# %%
m2 = MOC.from_ivorn('ivo://CDS/B/denis/denis', nside=64)
print(m2.sky_fraction)
m2.plot()
# Out:
# 0.5222574869791666
