# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

from mocpy import MOC

# %% [markdown]
# First, we retrieve the MOC for VizieR table VIII/84/7c

# %%
moc = MOC.from_vizier_table('VIII/84/7c', nside=64)
moc.plot(coord='C')

# %% [markdown]
# Then, we query Hipparcos catalogue to get all sources in the MOC coverage

# %%
#table = moc.query_simbad(10000)
table = moc.query_vizier_table('I/239/hip_main', max_rows=100000)
print(table)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-ded2ceed93ca> in <module>()
#       1 #table = moc.query_simbad(10000)
# ----> 2 table = moc.query_vizier_table('I/239/hip_main', max_rows=100000)
#       3 print(table)
#
# /usr/local/lib/python3.5/dist-packages/mocpy/moc.py in query_vizier_table(self, table_id, max_rows)
#     377         """
#     378
# --> 379         return self._query(table_id, max_rows)
#     380
#     381     def _query(self, resource_id, max_rows):
#
# /usr/local/lib/python3.5/dist-packages/mocpy/moc.py in _query(self, resource_id, max_rows)
#     408
#     409         from astropy.io.votable import parse_single_table
# --> 410         table = parse_single_table(tmp_vot).to_table()
#     411
#     412         # finally delete temp files
#
# ~/.local/lib/python3.5/site-packages/astropy/io/votable/table.py in parse_single_table(source, **kwargs)
#     155         kwargs['table_number'] = 0
#     156
# --> 157     votable = parse(source, **kwargs)
#     158
#     159     return votable.get_first_table()
#
# ~/.local/lib/python3.5/site-packages/astropy/io/votable/table.py in parse(source, columns, invalid, pedantic, chunk_size, table_number, table_id, filename, unit_format, datatype_mapping, _debug_python_based_parser)
#     137         _debug_python_based_parser=_debug_python_based_parser) as iterator:
#     138         return tree.VOTableFile(
# --> 139             config=config, pos=(1, 1)).parse(iterator, config)
#     140
#     141
#
# ~/.local/lib/python3.5/site-packages/astropy/io/votable/tree.py in parse(self, iterator, config)
#    3339         config['_current_table_number'] = 0
#    3340
# -> 3341         for start, tag, data, pos in iterator:
#    3342             if start:
#    3343                 if tag == 'xml':
#
# ValueError: 1:0: syntax error

# %% [markdown]
# Finally, we plot the positions of the sources in the table to check if they lie in the MOC coverage

# %%
moc_table = MOC.from_table(table, '_RAJ2000', '_DEJ2000', 7)
moc_table.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1b428c4478d6> in <module>()
# ----> 1 moc_table = MOC.from_table(table, '_RAJ2000', '_DEJ2000', 7)
#       2 moc_table.plot()
#
# NameError: name 'table' is not defined
